# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("train.csv")

# %% [markdown]
# # Analysis of Data

# %%
# Shape of data set
df.shape
# Out:
# (891, 12)

# %%
# All columns of data set
df.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age',
#        u'SibSp', u'Parch', u'Ticket', u'Fare', u'Cabin', u'Embarked'],
#       dtype='object')

# %%
# Describing dataset
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Describe dataset
df.describe(include = ['O'])
# Out:
#                              Name   Sex    Ticket        Cabin Embarked
# count                         891   891       891          204      889
# unique                        891     2       681          147        3
# top     Graham, Mr. George Edward  male  CA. 2343  C23 C25 C27        S
# freq                            1   577         7            4      644

# %% [markdown]
# This shows that there are duplicate Ticket number and Cabins shared. The highest number of duplicate ticket number is "CA. 2343". It has been repeated 7 times. Similarly, the highest number of people using the same cabin is 4. They are using cabin number "C23 C25 C27".
#
# We also see that 644 people were embarked from port "S".
#
# Among 891 rows, 577 were Male and the rest were Female.

# %%
# Shows top 5 rows of the data set
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Below is a brief information about each columns of the dataset:
#
# PassengerId: An unique index for passenger rows. It starts from 1 for first row and increments by 1 for every new rows.
#
# Survived: Shows if the passenger survived or not. 1 stands for survived and 0 stands for not survived.
#
# Pclass: Ticket class. 1 stands for First class ticket. 2 stands for Second class ticket. 3 stands for Third class ticket.
#
# Name: Passenger's name. Name also contain title. "Mr" for man. "Mrs" for woman. "Miss" for girl. "Master" for boy.
#
# Sex: Passenger's sex. It's either Male or Female.
#
# Age: Passenger's age. "NaN" values in this column indicates that the age of that particular passenger has not been recorded.
#
# SibSp: Number of siblings or spouses travelling with each passenger.
#
# Parch: Number of parents of children travelling with each passenger.
#
# Ticket: Ticket number.
#
# Fare: How much money the passenger has paid for the travel journey.
#
# Cabin: Cabin number of the passenger. "NaN" values in this column indicates that the cabin number of that particular passenger has not been recorded.
#
# Embarked: Port from where the particular passenger was embarked/boarded.

# %%
# Shows bottom 5 rows of the data set.
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# To check if there is any missing data.
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop([0,3,6,7,8,10],axis = 0)
# Out:
#      Survived  Pclass     Sex  Age      Fare Embarked
# 1           1       1  female   51   71.2833        C
# 2           1       3  female   34    7.9250        S
# 4           0       3    male   47    8.0500        S
# 5           0       3    male  110    8.4583        Q
# 9           1       2  female   18   30.0708        C
# 11          1       1  female   74   26.5500        S
# 12          0       3    male   25    8.0500        S
# 13          0       3    male   52   31.2750        S
# 14          0       3  female   18    7.8542        S
# 15          1       2  female   70   16.0000        S
# 16          0       3    male    6   29.1250        Q
# 17          1       2    male   88   13.0000        S
# 18          0       3  female   41   18.0000        S
# 19          1       3  female   96    7.2250        C
# 20          0       2    male   47   26.0000        S
# 21          1       2    male   45   13.0000        S
# ...

# %%
# Cabin is dropped thus age and embarked have missing values.
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Sex', u'Age', u'SibSp',
#        u'Parch', u'Ticket', u'Fare', u'Embarked'],
#       dtype='object')

# %%
# Missing values in Age are filled using mean
from sklearn.preprocessing import Imputer
age_imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)
age_imputer = age_imputer.fit(df.iloc[ : , [5]])
df.iloc[:, [5]] = age_imputer.transform(df.iloc[:, [5]])
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0    1.0      0
# 1            2         1       1  female  38.0    1.0      0
# 2            3         1       3  female  26.0    0.0      0
# 3            4         1       1  female  35.0    1.0      0
# 4            5         0       3    male  35.0    0.0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
#Missing values in Embarked
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'] = df['Embarked'].fillna('S')

# %%
survived = df[df['Survived'] == 1]
survived
# Out:
#      PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch  \
# 1              2         1       1  female   51    1.0      0
# 2              3         1       3  female   34    0.0      0
# 3              4         1       1  female   47    1.0      0
# 8              9         1       3  female   35    0.0      2
# 9             10         1       2  female   18    1.0      0
# 10            11         1       3  female    8    1.0      1
# 11            12         1       1  female   74    0.0      0
# 15            16         1       2  female   70    0.0      0
# 17            18         1       2    male   88    0.0      0
# 19            20         1       3  female   96    0.0      0
# 21            22         1       2    male   45    0.0      0
# 22            23         1       3  female   20    0.0      0
# 23            24         1       1    male   36    0.0      0
# 25            26         1       3  female   51    1.0      5
# ...

# %%
# Missing values in age are filled using mean thus only embarked left with missing values.
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
df.Embarked.value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#Check missing data again
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %% [markdown]
# # Relationship between Features and Survival
# In this section, we analyze relationship between different features with respect to Survival. We see how different feature values show different survival chance. We also plot different kinds of diagrams to visualize our data and findings.

# %%
df[df['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass     Sex    Age  SibSp  Parch  \
# 1              2         1       1  female  38.00    1.0      0
# 2              3         1       3  female  26.00    0.0      0
# 3              4         1       1  female  35.00    1.0      0
# 8              9         1       3  female  27.00    0.0      2
# 9             10         1       2  female  14.00    1.0      0
# 10            11         1       3  female   4.00    1.0      1
# 11            12         1       1  female  58.00    0.0      0
# 15            16         1       2  female  55.00    0.0      0
# 17            18         1       2    male    NaN    0.0      0
# 19            20         1       3  female    NaN    0.0      0
# 21            22         1       2    male  34.00    0.0      0
# 22            23         1       3  female  15.00    0.0      0
# 23            24         1       1    male  28.00    0.0      0
# 25            26         1       3  female  38.00    1.0      5
# ...

# %%
not_survived = df[df['Survived'] == 1]
not_survived
# Out:
#      PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch  \
# 1              2         1       1  female   51    1.0      0
# 2              3         1       3  female   34    0.0      0
# 3              4         1       1  female   47    1.0      0
# 8              9         1       3  female   35    0.0      2
# 9             10         1       2  female   18    1.0      0
# 10            11         1       3  female    8    1.0      1
# 11            12         1       1  female   74    0.0      0
# 15            16         1       2  female   70    0.0      0
# 17            18         1       2    male   88    0.0      0
# 19            20         1       3  female   96    0.0      0
# 21            22         1       2    male   45    0.0      0
# 22            23         1       3  female   20    0.0      0
# 23            24         1       1    male   36    0.0      0
# 25            26         1       3  female   51    1.0      5
# ...

# %%
print 'Survived ', survived.head(), '\n\nNot Survived ', not_survived.head()
# Out:
# Survived     PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 1            2         1       1  female  38.0    1.0      0
# 2            3         1       3  female  26.0    0.0      0
# 3            4         1       1  female  35.0    1.0      0
# 8            9         1       3  female  27.0    0.0      2
# 9           10         1       2  female  14.0    1.0      0
#
#              Ticket     Fare Embarked
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 8            347742  11.1333        S
# 9            237736  30.0708        C
#
# Not Survived     PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 1            2         1       1  female  38.0    1.0      0
# 2            3         1       3  female  26.0    0.0      0
# 3            4         1       1  female  35.0    1.0      0
# 8            9         1       3  female  27.0    0.0      2
# ...

# %% [markdown]
# # Pclass and Survival

# %%
print "Survived: %i (%f%%)" % (len(survived), float(len(survived))/len(df)*100.0)
print "Not Survived: %i (%f%%)" % (len(not_survived), float(len(not_survived))/len(df)*100.0)
print "Total : %i" % len(df)
# Out:
# Survived: 342 (38.383838%)
# Not Survived: 342 (38.383838%)
# Total : 891

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.groupby('Pclass').Survived.value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %% [markdown]
# # Sex vs Survival

# %%
#Value Counts of Sex
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#Survival grouped by Sex
df.groupby('Sex').Survived.value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %% [markdown]
# # Age vs Survival

# %%
df.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
# 28.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 27.00    18
# 35.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 20.00    15
# 33.00    15
# 23.00    15
# 34.00    15
# 39.00    14
# 17.00    13
# 42.00    13
# 40.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 47.00     9
#          ..
# 71.00     2
# 59.00     2
# 63.00     2
# 0.83      2
# 30.50     2
# 70.00     2
# 57.00     2
# 0.75      2
# 13.00     2
# 10.00     2
# 64.00     2
# 40.50     2
# 32.50     2
# 45.50     2
# 20.50     1
# 24.50     1
# 0.67      1
# 14.50     1
# 0.92      1
# 74.00     1
# 34.50     1
# 80.00     1
# 12.00     1
# 36.50     1
# 53.00     1
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
df.groupby('Age').Survived.value_counts()
# Out:
# Age    Survived
# 0.42   1           1
# 0.67   1           1
# 0.75   1           2
# 0.83   1           2
# 0.92   1           1
# 1.00   1           5
#        0           2
# 2.00   0           7
#        1           3
# 3.00   1           5
#        0           1
# 4.00   1           7
#        0           3
# 5.00   1           4
# 6.00   1           2
#        0           1
# 7.00   0           2
#        1           1
# 8.00   0           2
#        1           2
# 9.00   0           6
#        1           2
# 10.00  0           2
# 11.00  0           3
#        1           1
# 12.00  1           1
# 13.00  1           2
# 14.00  0           3
#        1           3
# 14.50  0           1
#                   ..
# 51.00  0           5
#        1           2
# 52.00  0           3
#        1           3
# 53.00  1           1
# 54.00  0           5
#        1           3
# 55.00  0           1
#        1           1
# 55.50  0           1
# 56.00  0           2
# ...

# %% [markdown]
# # Fare vs Survival

# %%
df.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 0.0000      15
# 7.2292      15
# 7.8542      13
# 8.6625      13
# 7.2500      13
# 7.2250      12
# 16.1000      9
# 9.5000       9
# 24.1500      8
# 15.5000      8
# 56.4958      7
# 52.0000      7
# 14.5000      7
# 14.4542      7
# 69.5500      7
# 7.0500       7
# 31.2750      7
# 46.9000      6
# 30.0000      6
# 7.7958       6
# 39.6875      6
#             ..
# 7.1417       1
# 42.4000      1
# 211.5000     1
# 12.2750      1
# 61.1750      1
# 8.4333       1
# 51.4792      1
# 7.8875       1
# 8.6833       1
# 7.5208       1
# 34.6542      1
# 28.7125      1
# 25.5875      1
# 7.7292       1
# 12.2875      1
# 8.6542       1
# 8.7125       1
# 61.3792      1
# 6.9500       1
# 9.8417       1
# 8.3000       1
# 13.7917      1
# 9.4750       1
# 13.4167      1
# 26.3875      1
# 8.4583       1
# 9.8375       1
# ...

# %%
df.groupby('Fare').Survived.value_counts()
# Out:
# Fare      Survived
# 0.0000    0           14
#           1            1
# 4.0125    0            1
# 5.0000    0            1
# 6.2375    0            1
# 6.4375    0            1
# 6.4500    0            1
# 6.4958    0            2
# 6.7500    0            2
# 6.8583    0            1
# 6.9500    0            1
# 6.9750    0            1
#           1            1
# 7.0458    0            1
# 7.0500    0            7
# 7.0542    0            2
# 7.1250    0            4
# 7.1417    1            1
# 7.2250    0            9
#           1            3
# 7.2292    0           11
#           1            4
# 7.2500    0           12
#           1            1
# 7.3125    0            1
# 7.4958    0            2
#           1            1
# 7.5208    0            1
# 7.5500    0            3
#           1            1
#                       ..
# 106.4250  0            1
#           1            1
# 108.9000  0            1
#           1            1
# 110.8833  1            3
# ...

# %% [markdown]
# # Embarked vs Survival

# %%
df.Embarked.value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.groupby('Embarked').Survived.value_counts()
# Out:
# Embarked  Survived
# C         1            93
#           0            75
# Q         0            47
#           1            30
# S         0           427
#           1           219
# Name: Survived, dtype: int64

# %% [markdown]
# # Visualising Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns
sns.set()

# %% [markdown]
# # Age vs Survival

# %%
sns.barplot(x='Age', y='Survived', data=df)
sns.despine()

# %% [markdown]
# # PClass vs Survival

# %%
sns.barplot(x='Pclass', y='Survived', data=df)
sns.despine()

# %% [markdown]
# # Sex vs Survival

# %%
sns.barplot(x='Sex', y='Survived', data=df)
sns.despine()

# %% [markdown]
# # Fare vs Survival

# %%
sns.barplot(x='Fare', y='Survived', data=df)
sns.despine()

# %% [markdown]
# # Embarked vs Survived

# %%
sns.barplot(x='Embarked', y='Survived', data=df)
sns.despine()

# %%
sns.violinplot(x='Pclass', y='Age', hue='Survived', data=df, split=True)
sns.despine()

# %% [markdown]
# # Pclass & Age vs Survival

# %%
sns.violinplot(x='Sex', y='Age', hue='Survived', data=df, split=True)
sns.despine()

# %%
#Encoding Sex
from sklearn.preprocessing import LabelEncoder
labelencoder_sex = LabelEncoder()
df.iloc[:, [4]] = labelencoder_sex.fit_transform(df.iloc[:, [4]])
print df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    male   28    1.0      0         A/5 21171
# 1            2         1       1  female   51    1.0      0          PC 17599
# 2            3         1       3  female   34    0.0      0  STON/O2. 3101282
# 3            4         1       1  female   47    1.0      0            113803
# 4            5         0       3    male   47    0.0      0            373450
#
#       Fare Embarked
# 0   7.2500        S
# 1  71.2833        C
# 2   7.9250        S
# 3  53.1000        S
# 4   8.0500        S

# %%
#Encoding Embarked
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_embarked = LabelEncoder()
df.iloc[:,[9]] = labelencoder_embarked.fit_transform(df.iloc[:,[9]])
print df.head()
# Out:
#    Survived  Sex  Age     Fare  Pclass_1  Pclass_2  Pclass_3  Embarked_C  \
# 0         0    1   28   7.2500         0         0         1           0
# 1         1    0   51  71.2833         1         0         0           1
# 2         1    0   34   7.9250         0         0         1           0
# 3         1    0   47  53.1000         1         0         0           0
# 4         0    1   47   8.0500         0         0         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
#One Hot Encoding Pclass and Embarked
df = pd.get_dummies(df, columns=['Pclass', 'Embarked'])
df.head()
# Out:
#    Survived     Sex  Age     Fare  Pclass_1  Pclass_2  Pclass_3  Embarked_C  \
# 0         0    male   28   7.2500         0         0         1           0
# 1         1  female   51  71.2833         1         0         0           1
# 2         1  female   34   7.9250         0         0         1           0
# 3         1  female   47  53.1000         1         0         0           0
# 4         0    male   47   8.0500         0         0         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
df['Sex'] = df['Sex'].apply(lambda x : 1 if x == 'male' else 0)

# %%
df['Sex'] = LabelEncoder().fit_transform(df['Sex'])

# %%
# Out:
#      Age
# 0     28
# 1     51
# 2     34
# 3     47
# 4     47
# 5    110
# 6     69
# 7      6
# 8     35
# 9     18
# 10     8
# 11    74
# 12    25
# 13    52
# 14    18
# 15    70
# 16     6
# 17    88
# 18    41
# 19    96
# 20    47
# 21    45
# 22    20
# 23    36
# 24    12
# 25    51
# 26   121
# 27    24
# 28   104
# 29   111
# ..   ...
# 861   27
# 862   63
# 863  122
# 864   31
# 865   56
# 866   35
# 867   41
# 868  113
# 869    8
# 870   34
# 871   62
# 872   44
# 873   62
# 874   36
# 875   20
# 876   25
# 877   24
# 878  108
# 879   72
# 880   33
# 881   44
# 882   28
# 883   36
# 884   33
# 885   52
# 886   35
# 887   24
# 888   90
# 889   34
# 890   42
#
# [891 rows x 1 columns]

# %%
X = df.drop(['Survived'],axis = 1)
y = df['Survived']
#print X.shape, y.shape
X.head()
# Out:
#    Sex  Age     Fare  Pclass_1  Pclass_2  Pclass_3  Embarked_C  Embarked_Q  \
# 0    1   28   7.2500         0         0         1           0           0
# 1    0   51  71.2833         1         0         0           1           0
# 2    0   34   7.9250         0         0         1           0           0
# 3    0   47  53.1000         1         0         0           0           0
# 4    1   47   8.0500         0         0         1           0           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
print X_train.shape, y_train.shape
# Out:
# (623, 9) (623L,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
clf = LogisticRegression()
clf.fit(X_train, y_train) #Trivia : What does ravel do?
y_pred_log_reg = clf.predict(X_test)
acc_log_reg = round( accuracy_score(y_pred_log_reg, y_test) * 100, 2)
print (str(acc_log_reg) + ' %')
# Out:
# 79.48 %

# %%
X_train.head()
# Out:
#      Sex  Age     Fare  Pclass_1  Pclass_2  Pclass_3  Embarked_C  Embarked_Q  \
# 857    1   66  26.5500         1         0         0           0           0
# 52     0   64  76.7292         1         0         0           1           0
# 386    1    5  46.9000         0         0         1           0           0
# 124    1   69  77.2875         1         0         0           0           0
# 578    0  254  14.4583         0         0         1           1           0
#
#      Embarked_S
# 857           1
# 52            0
# 386           1
# 124           1
# 578           0

# %%
X_train
# Out:
#      Sex  Age      Fare  Pclass_1  Pclass_2  Pclass_3  Embarked_C  Embarked_Q  \
# 857    1   66   26.5500         1         0         0           0           0
# 52     0   64   76.7292         1         0         0           1           0
# 386    1    5   46.9000         0         0         1           0           0
# 124    1   69   77.2875         1         0         0           0           0
# 578    0  254   14.4583         0         0         1           1           0
# 549    1   12   36.7500         0         1         0           0           0
# 118    1   31  247.5208         1         0         0           1           0
# 12     1   25    8.0500         0         0         1           0           0
# 157    1   39    8.0500         0         0         1           0           0
# 127    1   31    7.1417         0         0         1           0           0
# 653    0  207    7.8292         0         0         1           0           1
# ...

# %%
df.describe()
# Out:
#          Survived         Sex         Age        Fare    Pclass_1    Pclass_2  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    0.647587   66.090909   32.204208    0.242424    0.206510
# std      0.486592    0.477990   61.517218   49.693429    0.428790    0.405028
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   28.000000    7.910400    0.000000    0.000000
# 50%      0.000000    1.000000   42.000000   14.454200    0.000000    0.000000
# 75%      1.000000    1.000000   69.000000   31.000000    0.000000    0.000000
# max      1.000000    1.000000  264.000000  512.329200    1.000000    1.000000
#
#          Pclass_3  Embarked_C  Embarked_Q  Embarked_S
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.551066    0.188552    0.086420    0.725028
# std      0.497665    0.391372    0.281141    0.446751
# ...

# %%
g = sns.countplot(x = 'Survived', data = df)
g.set_xlabel("1 = Survived, 0 = dead")
g.set_title("Survival Count Plot")
sns.despine()

# %%
p = sns.countplot(x = 'Sex', data = df)
p.set_xlabel("1 = Survived, 0 = dead")
p.set_title("Survival Count Plot")
sns.despine()

# %%
p = sns.countplot(x = 'Age' , data = df) 
p.set_title("Survival Count Plot")
sns.despine()

# %%
s = sns.boxplot(y = 'Age' , data = df)
sns.despine()

# %%
s = sns.boxplot(x = 'Age' , data = df)
sns.despine()

# %%
df.Age.describe()
# Out:
# count    891.000000
# mean      66.090909
# std       61.517218
# min        0.000000
# 25%       28.000000
# 50%       42.000000
# 75%       69.000000
# max      264.000000
# Name: Age, dtype: float64

# %%
sns.heatmap(df.corr())

# %%
sns.set(color_codes=True)
ax = sns.regplot(x=df["Fare"], y=df["Survived"], marker = '+' , fit_reg = False)

# %%
df.isnull().sum()
# Out:
# Survived      0
# Sex           0
# Age           0
# Fare          0
# Pclass_1      0
# Pclass_2      0
# Pclass_3      0
# Embarked_C    0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %%
df.tail()
# Out:
#      Survived  Sex  Age   Fare  Pclass_1  Pclass_2  Pclass_3  Embarked_C  \
# 886         0    1   35  13.00         0         1         0           0
# 887         1    0   24  30.00         1         0         0           0
# 888         0    0   90  23.45         0         0         1           0
# 889         1    1   34  30.00         1         0         0           1
# 890         0    1   42   7.75         0         0         1           0
#
#      Embarked_Q  Embarked_S
# 886           0           1
# 887           0           1
# 888           0           1
# 889           0           0
# 890           1           0

# %%
df.to_csv('titanic_prepared_data.csv', index=False)

# %%
df = pd.read_csv('titanic_prepared_data.csv')
df.head()
# Out:
#    Survived  Sex  Age     Fare  Pclass_1  Pclass_2  Pclass_3  Embarked_C  \
# 0         0    1   28   7.2500         0         0         1           0
# 1         1    0   51  71.2833         1         0         0           1
# 2         1    0   34   7.9250         0         0         1           0
# 3         1    0   47  53.1000         1         0         0           0
# 4         0    1   47   8.0500         0         0         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1
